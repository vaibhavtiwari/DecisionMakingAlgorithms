# %% [markdown]
# # [Name of the distribution] Probability Distribution

# %% [markdown]
# ## 1. Definition

# %% [markdown]
# ## 2. Intuition

# %% [markdown]
# ## 3. Parameter

# %% [markdown]
# ## 4. Support

# %% [markdown]
# ## 5. Probability Mass Function

# %% [markdown]
# ## 6. Cumulative Distribution Function

# %% [markdown]
# ## 7. Moments

# %% [markdown]
# ## 8. NumPy Implementation
