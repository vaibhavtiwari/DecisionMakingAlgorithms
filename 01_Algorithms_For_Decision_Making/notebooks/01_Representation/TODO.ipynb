# %% [markdown]
# TODO:
#
# - 01_Joint_Distribution.ipynb
# - 02_Marginalization.ipynb
# - 03_Conditional_Probability.ipynb
# - 04_Chain_Rule.ipynb
# - 05_Bayes_Theorem.ipynb
# - 06_Factors.ipynb
# - 07_Factor_Operations.ipynb
# - 08_Bayesian_Networks.ipynb
# - 09_Variable_Elimination.ipynb
# - 10_Belief_Propagation.ipynb
