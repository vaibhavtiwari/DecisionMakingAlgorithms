# %% [markdown]
# Inference in BN
#         │
#         ▼
# Naive Bayes
#         │
#         ▼
# Variable Elimination
#         │
#         ▼
# Belief Propagation
#         │
#         ▼
# Sampling
#         │
#         ├─────────────► Direct Sampling
#         │
#         ├─────────────► Likelihood Weighting
#         │
#         └─────────────► Gibbs Sampling
#         │
#         ▼
# Gaussian Inference
